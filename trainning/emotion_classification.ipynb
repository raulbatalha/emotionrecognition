# %%
from src.train import train_model
from src.utils import plot_training_history

folder_path = "./data/raw/"
model, history = train_model(folder_path)

plot_training_history(history)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# Epoch 1/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2966 - loss: 1.8692
# Epoch 1: val_accuracy improved from -inf to 0.42656, saving model to ../../models/model.keras
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 409s 2s/step - accuracy: 0.2968 - loss: 1.8685 - val_accuracy: 0.4266 - val_loss: 1.4824 - learning_rate: 0.0010
# Epoch 2/48
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 6:15 2s/step - accuracy: 0.4062 - loss: 1.5372
# Epoch 2: val_accuracy improved from 0.42656 to 0.42756, saving model to ../../models/model.keras
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.4062 - loss: 1.5372 - val_accuracy: 0.4276 - val_loss: 1.4707 - learning_rate: 0.0010
# Epoch 3/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4605 - loss: 1.4160
# Epoch 3: val_accuracy did not improve from 0.42756
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 408s 2s/step - accuracy: 0.4606 - loss: 1.4159 - val_accuracy: 0.4158 - val_loss: 1.6713 - learning_rate: 0.0010
# Epoch 4/48
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 6:34 2s/step - accuracy: 0.4375 - loss: 1.4364
# Epoch 4: val_accuracy did not improve from 0.42756
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 75ms/step - accuracy: 0.4375 - loss: 1.4364 - val_accuracy: 0.4196 - val_loss: 1.6682 - learning_rate: 0.0010
# Epoch 5/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5242 - loss: 1.2524
# Epoch 5: val_accuracy improved from 0.42756 to 0.53835, saving model to ../../models/model.keras
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.5242 - loss: 1.2524 - val_accuracy: 0.5384 - val_loss: 1.2216 - learning_rate: 0.0010
# Epoch 6/48
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 5:58 2s/step - accuracy: 0.6484 - loss: 1.1024
# Epoch 6: val_accuracy did not improve from 0.53835
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 19s 76ms/step - accuracy: 0.6484 - loss: 1.1024 - val_accuracy: 0.5337 - val_loss: 1.2476 - learning_rate: 0.0010
# Epoch 7/48
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5690 - loss: 1.1456
# Epoch 7: val_accuracy did not improve from 0.53835
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.5689 - loss: 1.1456 - val_accuracy: 0.5189 - val_loss: 1.3386 - learning_rate: 0.0010
# Epoch 8/48
#   1/225 ━━━━━━━━━━━━━━━━━━━━ 6:01 2s/step - accuracy: 0.5625 - loss: 1.1782
# Epoch 8: val_accuracy did not improve from 0.53835
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 70ms/step - accuracy: 0.5625 - loss: 1.1782 - val_accuracy: 0.5141 - val_loss: 1.3506 - learning_rate: 0.0010
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 5.
